# %%
# Load Modules
# Note: In Notebooks, working directory is usually the notebook file location
source("../../src/smoothing/local_linear_regression.R")
source("../../src/smoothing/bw_cv_final.R")

options(repr.plot.width=10, repr.plot.height=6) # Resize plots
